# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from google.colab import userdata
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %%
  from google.colab import userdata
  from huggingface_hub import login
  login(token=userdata.get("HF_TOKEN"))

# %%
# !pip install anomalib -q

# %%
cd /content/drive/Othercomputers/mynotebook/multimodal-anomaly-report-generation
# Out:
# /content/drive/Othercomputers/mynotebook/multimodal-anomaly-report-generation

# %%
pip install transformers==4.52.4 -q

# %%
pip install bitsandbytes -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 35.3 MB/s eta 0:00:00

# %%
# !uv pip install langchain_chroma
# !uv pip install langchain_community
# !uv pip install huggingface_hub
# !uv pip install langchain_huggingface
# Out:
# Using Python 3.12.12 environment at: /usr
# Audited 1 package in 104ms
# Using Python 3.12.12 environment at: /usr
# Audited 1 package in 109ms
# Using Python 3.12.12 environment at: /usr
# Audited 1 package in 105ms
# Using Python 3.12.12 environment at: /usr
# Audited 1 package in 97ms

# %%
# !python scripts/run_experiment.py \
  --config configs/experiment.yaml \
  --ad-model patchcore \
  --sample-per-folder 3 \
  --sample-seed 42 \
  --output-dir outputs/eval_ablation/gemma_qat \
  --rag \
  --batch-mode true
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771650575.423714   16782 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771650575.431267   16782 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771650575.450650   16782 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771650575.450683   16782 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python scripts/run_experiment.py \
  --config configs/experiment.yaml \
  --output-dir outputs/eval_ablation/gemma_qat2
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# ...
# MMAD Experiment Runner
# ...
# Experiment:  no_ad_gemma3-12b-qat_1shot
# LLM:         gemma3-12b-qat
# AD model:    none
# RAG:         disabled
# Few-shot:    1
# Template:    Random_template
# Image size:  (384, 384)
# Images:      99 / 4224
# Data root:   /content/drive/Othercomputers/mynotebook/multimodal-anomaly-report-generation/dataset/MMAD
# Output:      outputs/eval_ablation/gemma_qat/answers_1_shot_gemma3-12b-qat_Random_template_99img.json
# ...
#
# Filtered MMAD json: 99 images -> outputs/eval_ablation/gemma_qat/_sampled_mmad.json
#
# ...

# %%
# !python scripts/compare_results.py --sort accuracy --output-dir outputs/eval_ablation/gemma_qat/
# Out:
# ...
# Experiment               LLM            AD Model       Few-shotAccuracyImages  ErrorsTime    s/img  Timestamp
# ------------------------------------------------------------------------------------------------------------------------
# patchcore_gemma3-12b-qat gemma3-12b-qat patchcore      1       76.2%   99      0     603s    6.1s   2026-02-21T14:20:43
# no_ad_gemma3-12b-qat_1sh gemma3-12b-qat none           1       60.0%   99      0     889s    9.0s   2026-02-21T13:38:46
# ...
#
# Total experiments: 2
# Best accuracy: 76.2% (patchcore_gemma3-12b-qat_1shot_rag)

# %%
# !python scripts/run_experiment.py \
  --config configs/experiment.yaml \
  --output-dir outputs/eval_ablation/gemini_new_rag
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# ...
# MMAD Experiment Runner
# ...
# Experiment:  no_ad_gemini-2.5-flash-lite_1shot
# LLM:         gemini-2.5-flash-lite
# AD model:    none
# RAG:         disabled
# Few-shot:    1
# Template:    Random_template
# Image size:  (384, 384)
# Images:      99 / 4224
# Data root:   /content/drive/Othercomputers/mynotebook/multimodal-anomaly-report-generation/dataset/MMAD
# Output:      outputs/eval_ablation/gemini_new_rag/answers_1_shot_gemini-2.5-flash-lite_Random_template_99img.json
# ...
#
# Filtered MMAD json: 99 images -> outputs/eval_ablation/gemini_new_rag/_sampled_mmad.json
#
# Evaluating: 100%|████████████████████████| 99/99 [01:27<00:00,  1.13it/s, acc=69.6%, done=99, err=0]
#
# ...
# Latency by Class
# ...
#   Class                               N   Avg(s)   Total(s)
# ------------------------------------------------------------
#   GoodsAD/cigarette_box               6     1.39       8.34
# ...

# %%
# !python scripts/run_experiment.py \
  --config configs/experiment.yaml \
  --ad-model patchcore \
  --sample-per-folder 10 \
  --sample-seed 42 \
  --output-dir outputs/eval_ablation/gemini_lite_try \
  --rag \
  --batch-mode true
# Out:
# Stratified sampling: 10장/폴더, 33폴더
#   Total: 4224 -> Sampled: 330 (normal=100, anomaly=230)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771659914.045125   58125 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771659914.052932   58125 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771659914.073501   58125 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771659914.073538   58125 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python scripts/compare_results.py --sort accuracy --output-dir outputs/eval_ablation/gemini_new_rag/ outputs/eval_ablation/gemma_qat/
# Out:
# ...
# Experiment               LLM            AD Model       Few-shotAccuracyImages  ErrorsTime    s/img  Timestamp
# ------------------------------------------------------------------------------------------------------------------------
# patchcore_gemini-2.5-fla gemini-2.5-fla patchcore      1       82.7%   99      0     72s     0.7s   2026-02-21T16:10:26
# patchcore_gemini_1shot_r gemini         patchcore      1       81.1%   99      0     1100s   11.1s  2026-02-21T16:02:36
# no_ad_gemini_1shot       gemini         none           1       76.7%   99      0     998s    10.1s  2026-02-21T15:42:43
# patchcore_gemma3-12b-qat gemma3-12b-qat patchcore      1       76.2%   99      0     603s    6.1s   2026-02-21T14:20:43
# no_ad_gemini-2.5-flash-l gemini-2.5-fla none           1       69.6%   99      0     87s     0.9s   2026-02-21T16:07:37
# no_ad_gemma3-12b-qat_1sh gemma3-12b-qat none           1       60.0%   99      0     889s    9.0s   2026-02-21T13:38:46
# ...
#
# Total experiments: 6
# ...

# %%
# !python scripts/seed_db.py \
--config configs/experiment.yaml \
--output sample_data.99imgs.json
# Out:
# ...
# DB Seed 설정
# ...
# Config:       configs/experiment.yaml
# DSN:          없음 (JSON만 저장)
# MMAD JSON:    dataset/MMAD/mmad_10classes.json
# N / N/folder: None / 3
# Seed:         42
# Clear:        False
# Output JSON:  sample_data.99imgs.json
#
# MMAD: 4224 이미지 → 99장 샘플링 (3장/폴더)
# 생성된 레코드: 99개
#
# JSON 저장: sample_data.99imgs.json
