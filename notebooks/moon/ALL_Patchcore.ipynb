# %%
import os
os.environ["TQDM_DISABLE"] = "1"

import tqdm
from tqdm import tqdm as tqdm_class

_original_init = tqdm_class.__init__
def _patched_init(self, *args, **kwargs):
    kwargs["disable"] = True
    _original_init(self, *args, **kwargs)
tqdm_class.__init__ = _patched_init
tqdm.tqdm = tqdm_class

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import warnings
import sys
import time
import logging
logging.getLogger("anomalib").setLevel(logging.ERROR)
warnings.filterwarnings('ignore')

from tqdm import tqdm
from pathlib import Path
from collections import Counter, defaultdict
from PIL import Image

# %%
try:
    import google.colab
    from google.colab import drive
    # !uv pip install anomalib
    # !uv pip install open-clip-torch
    drive.mount('/content/drive', force_remount=True)
    PROJECT_ROOT = Path('/content/drive/Othercomputers/Mac/multiModal_anomaly_report') # 본인 경로 수정: Mac/Window
except ImportError:
    PROJECT_ROOT = Path.cwd().parents[1]

os.chdir(PROJECT_ROOT) # 현재 경로 수정
print(f"Current working directory: {os.getcwd()}")
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 94 packages in 1.64s
# Prepared 12 packages in 507ms
# Installed 12 packages in 20ms
#  + anomalib==2.2.0
#  + freia==0.2
#  + imagecodecs==2026.1.14
#  + jsonargparse==4.46.0
#  + kornia==0.8.2
#  + kornia-rs==0.1.10
#  + lightning==2.6.1
#  + lightning-utilities==0.15.2
#  + pytorch-lightning==2.6.1
#  + rich-argparse==1.7.2
#  + torchmetrics==1.8.2
#  + typeshed-client==2.8.2
# Using Python 3.12.12 environment at: /usr
# Resolved 49 packages in 95ms
# Prepared 2 packages in 37ms
# Installed 2 packages in 5ms
#  + ftfy==6.3.1
#  + open-clip-torch==3.2.0
# Mounted at /content/drive
# Current working directory: /content/drive/Othercomputers/Mac/multiModal_anomaly_report

# %% [markdown]
# ### Check config

# %%
# TODO: PATH 설정

# dataset path
DATA_ROOT = PROJECT_ROOT / "dataset" / "MMAD"

# config.yaml path
CONFIG_ROOT = PROJECT_ROOT / "configs"
RUNTIME_CONFIG_ROOT = CONFIG_ROOT / "runtime.yaml"
EVAL_CONFIG_ROOT = CONFIG_ROOT / "eval.yaml"

# output path
OUTPUT_ROOT = PROJECT_ROOT / "output"

# check (선택사항)
print(f"Project Root: {PROJECT_ROOT}")
print(f"Data Root: {DATA_ROOT}")
print(f"Config Root: {RUNTIME_CONFIG_ROOT}")
# Out:
# Project Root: /content/drive/Othercomputers/Mac/multiModal_anomaly_report
# Data Root: /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# Config Root: /content/drive/Othercomputers/Mac/multiModal_anomaly_report/configs/runtime.yaml

# %%
from src.utils import load_config, load_json, load_csv

# tqdm bar off
os.environ["TQDM_DISABLE"] = "1"

# TODO: runtime_config.yaml 확장/수정
config = load_config(RUNTIME_CONFIG_ROOT)
config
# Out:
# {'data': {'root': 'dataset/MMAD', 'output_root': './output'},
#  'anomaly': {'model': 'patchcore',
#   'patchcore': {'backbone': None,
#    'layers': None,
#    'coreset_sampling_ratio': None},
#   'winclip': {'class_name': None, 'k_shot': None, 'scales': None},
#   'efficientad': {'model_size': None,
#    'teacher_out_channels': None,
#    'visualizer': False,
#    'evaluator': True,
#    'imagenet_dir': 'imagenette/train'}},
#  'training': {'resume': False,
#   'train_batch_size': None,
#   'eval_batch_size': None,
#   'num_workers': 0,
#   'max_epochs': None},
#  'engine': {'accelerator': 'auto',
#   'enable_progress_bar': False,
#   'logger': 'wandb'},
#  'wandb': {'project': 'Anomaly_Detection', 'run_name': None},
#  'output': {'save_json': True}}

# %% [markdown]
# ### Train

# %%
from scripts.train_anomalib import Anomalibs

runner = Anomalibs() # default path: RUNTIME_CONFIG_ROOT
runner.fit_all()
# Out:
# TrainAnomalib - INFO - Initialized - model: patchcore, device: cuda
# Device: NVIDIA L4
# TrainAnomalib - INFO - Starting fit_all: 11 categories
# TrainAnomalib - INFO - [1/11] Training: GoodsAD/cigarette_box...
# TrainAnomalib - INFO - Fitting patchcore - GoodsAD/cigarette_box
# [1/11] Training: GoodsAD/cigarette_box...
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: moonstalker9010 (moonstalker9010-none) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:pytorch_lightning.utilities.rank_zero:You are using a CUDA device ('NVIDIA L4') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>wandb/run-20260205_131651-z491n39q</code>
# Syncing run <strong><a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/z491n39q' target="_blank">GoodsAD_cigarette_box</a></strong> to <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection</a>
#  View run at <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/z491n39q' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/z491n39q</a>
# wandb: Detected [openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai/
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name           ┃ Type           ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ pre_processor  │ PreProcessor   │      0 │ train │     0 │
# │ 1 │ post_processor │ PostProcessor  │      0 │ train │     0 │
# │ 2 │ evaluator      │ Evaluator      │      0 │ train │     0 │
# │ 3 │ model          │ PatchcoreModel │ 24.9 M │ train │     0 │
# └───┴────────────────┴────────────────┴────────┴───────┴───────┘
# Trainable params: 24.9 M
# Non-trainable params: 0
# Total params: 24.9 M
# Total estimated model params size (MB): 99
# Modules in train mode: 21
# Modules in eval mode: 174
# Total FLOPs: 0
# [Epoch 1/1] | AUROC=0.5000
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁</td></tr><tr><td>image_AUROC</td><td>▁</td></tr><tr><td>trainer/global_step</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>0</td></tr><tr><td>image_AUROC</td><td>0.5</td></tr><tr><td>trainer/global_step</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GoodsAD_cigarette_box</strong> at: <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/z491n39q' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/z491n39q</a><br> View project at: <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>wandb/run-20260205_131651-z491n39q/logs</code>
# TrainAnomalib - INFO - Fitting GoodsAD/cigarette_box done
# TrainAnomalib - INFO - [1/11] GoodsAD/cigarette_box done (715.7s)
# TrainAnomalib - INFO - [2/11] Training: GoodsAD/drink_bottle...
# TrainAnomalib - INFO - Fitting patchcore - GoodsAD/drink_bottle
# ✓ [1/11] GoodsAD/cigarette_box done (715.7s)
#
# [2/11] Training: GoodsAD/drink_bottle...
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: WARNING [wandb.login()] Changing session credentials to explicit value for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>wandb/run-20260205_132838-6kk44oqt</code>
# Syncing run <strong><a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/6kk44oqt' target="_blank">GoodsAD_drink_bottle</a></strong> to <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection</a>
#  View run at <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/6kk44oqt' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/6kk44oqt</a>
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name           ┃ Type           ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ pre_processor  │ PreProcessor   │      0 │ train │     0 │
# │ 1 │ post_processor │ PostProcessor  │      0 │ train │     0 │
# │ 2 │ evaluator      │ Evaluator      │      0 │ train │     0 │
# │ 3 │ model          │ PatchcoreModel │ 24.9 M │ train │     0 │
# └───┴────────────────┴────────────────┴────────┴───────┴───────┘
# Trainable params: 24.9 M
# Non-trainable params: 0
# Total params: 24.9 M
# Total estimated model params size (MB): 99
# Modules in train mode: 21
# Modules in eval mode: 174
# Total FLOPs: 0
# [Epoch 1/1] | AUROC=0.5000
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁</td></tr><tr><td>image_AUROC</td><td>▁</td></tr><tr><td>trainer/global_step</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>0</td></tr><tr><td>image_AUROC</td><td>0.5</td></tr><tr><td>trainer/global_step</td><td>22</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GoodsAD_drink_bottle</strong> at: <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/6kk44oqt' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/6kk44oqt</a><br> View project at: <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>wandb/run-20260205_132838-6kk44oqt/logs</code>
# TrainAnomalib - INFO - Fitting GoodsAD/drink_bottle done
# TrainAnomalib - INFO - [2/11] GoodsAD/drink_bottle done (2492.8s)
# TrainAnomalib - INFO - [3/11] Training: GoodsAD/drink_can...
# TrainAnomalib - INFO - Fitting patchcore - GoodsAD/drink_can
# ✓ [2/11] GoodsAD/drink_bottle done (2492.8s)
#
# [3/11] Training: GoodsAD/drink_can...
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: WARNING [wandb.login()] Changing session credentials to explicit value for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>wandb/run-20260205_141011-dxj94ujr</code>
# Syncing run <strong><a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/dxj94ujr' target="_blank">GoodsAD_drink_can</a></strong> to <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection</a>
#  View run at <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/dxj94ujr' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/dxj94ujr</a>
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name           ┃ Type           ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ pre_processor  │ PreProcessor   │      0 │ train │     0 │
# │ 1 │ post_processor │ PostProcessor  │      0 │ train │     0 │
# │ 2 │ evaluator      │ Evaluator      │      0 │ train │     0 │
# │ 3 │ model          │ PatchcoreModel │ 24.9 M │ train │     0 │
# └───┴────────────────┴────────────────┴────────┴───────┴───────┘
# Trainable params: 24.9 M
# Non-trainable params: 0
# Total params: 24.9 M
# Total estimated model params size (MB): 99
# Modules in train mode: 21
# Modules in eval mode: 174
# Total FLOPs: 0
# [Epoch 1/1] | AUROC=0.5000
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁</td></tr><tr><td>image_AUROC</td><td>▁</td></tr><tr><td>trainer/global_step</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>0</td></tr><tr><td>image_AUROC</td><td>0.5</td></tr><tr><td>trainer/global_step</td><td>7</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GoodsAD_drink_can</strong> at: <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/dxj94ujr' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/dxj94ujr</a><br> View project at: <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>wandb/run-20260205_141011-dxj94ujr/logs</code>
# TrainAnomalib - INFO - Fitting GoodsAD/drink_can done
# TrainAnomalib - INFO - [3/11] GoodsAD/drink_can done (639.3s)
# TrainAnomalib - INFO - [4/11] Training: GoodsAD/food_bottle...
# TrainAnomalib - INFO - Fitting patchcore - GoodsAD/food_bottle
# ✓ [3/11] GoodsAD/drink_can done (639.3s)
#
# [4/11] Training: GoodsAD/food_bottle...
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: WARNING [wandb.login()] Changing session credentials to explicit value for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>wandb/run-20260205_142050-s78hrivt</code>
# Syncing run <strong><a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/s78hrivt' target="_blank">GoodsAD_food_bottle</a></strong> to <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection</a>
#  View run at <a href='https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/s78hrivt' target="_blank">https://wandb.ai/moonstalker9010-none/Anomaly_Detection/runs/s78hrivt</a>
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name           ┃ Type           ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ pre_processor  │ PreProcessor   │      0 │ train │     0 │
# │ 1 │ post_processor │ PostProcessor  │      0 │ train │     0 │
# │ 2 │ evaluator      │ Evaluator      │      0 │ train │     0 │
# │ 3 │ model          │ PatchcoreModel │ 24.9 M │ train │     0 │
# └───┴────────────────┴────────────────┴────────┴───────┴───────┘
# Trainable params: 24.9 M
# Non-trainable params: 0
# Total params: 24.9 M
# Total estimated model params size (MB): 99
# Modules in train mode: 21
# Modules in eval mode: 174
# Total FLOPs: 0
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipython-input-3283221753.py in <cell line: 0>()
#       2
#       3 runner = Anomalibs() # default path: RUNTIME_CONFIG_ROOT
# ----> 4 runner.fit_all()
#
# /content/drive/Othercomputers/Mac/multiModal_anomaly_report/scripts/train_anomalib.py in fit_all(self)
#     473             logger.info(msg_start)
#     474             start = time.time()
# --> 475             self.fit(dataset, category)
#     476             elapsed = time.time() - start
#     477             msg_done = f"[{idx}/{total}] {dataset}/{category} done ({elapsed:.1f}s)"
#
# /content/drive/Othercomputers/Mac/multiModal_anomaly_report/scripts/train_anomalib.py in fit(self, dataset, category)
#     330         engine = self.get_engine(dataset, category, model=model, datamodule=datamodule)
#     331
# --> 332         engine.fit(datamodule=datamodule, model=model, ckpt_path=ckpt_path_to_use)
#     333
#     334         # WandB run 종료 (카테고리별로 별도 run)
#
# /usr/local/lib/python3.12/dist-packages/anomalib/engine/engine.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     410             self.trainer.validate(model, val_dataloaders, datamodule=datamodule, ckpt_path=ckpt_path)
#     411         else:
# --> 412             self.trainer.fit(model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     413
#     414     def validate(
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only)
#     582         self.training = True
#     583         self.should_stop = False
# --> 584         call._call_and_handle_interrupt(
#     585             self,
#     586             self._fit_impl,
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47         if trainer.strategy.launcher is not None:
#      48             return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 49         return trainer_fn(*args, **kwargs)
#      50
#      51     except _TunerExitException:
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py in _fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only)
#     628             model_connected=self.lightning_module is not None,
#     629         )
# --> 630         self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#     631
#     632         assert self.state.stopped
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py in _run(self, model, ckpt_path, weights_only)
#    1077         # RUN THE TRAINER
#    1078         # ----------------------------
# -> 1079         results = self._run_stage()
#    1080
#    1081         # ----------------------------
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py in _run_stage(self)
#    1121                 self._run_sanity_check()
#    1122             with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1123                 self.fit_loop.run()
#    1124             return None
#    1125         raise RuntimeError(f"Unexpected state {self.state}")
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/fit_loop.py in run(self)
#     215             try:
#     216                 self.on_advance_start()
# --> 217                 self.advance()
#     218                 self.on_advance_end()
#     219             except StopIteration:
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/fit_loop.py in advance(self)
#     463         with self.trainer.profiler.profile("run_training_epoch"):
#     464             assert self._data_fetcher is not None
# --> 465             self.epoch_loop.run(self._data_fetcher)
#     466
#     467     def on_advance_end(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/training_epoch_loop.py in run(self, data_fetcher)
#     152             try:
#     153                 self.advance(data_fetcher)
# --> 154                 self.on_advance_end(data_fetcher)
#     155             except StopIteration:
#     156                 break
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/training_epoch_loop.py in on_advance_end(self, data_fetcher)
#     404                 call._call_lightning_module_hook(self.trainer, "on_validation_model_zero_grad")
#     405
# --> 406             self.val_loop.run()
#     407             self.trainer.training = True
#     408             self.trainer._logger_connector._first_loop_iter = first_loop_iter
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/utilities.py in _decorator(self, *args, **kwargs)
#     177             context_manager = torch.no_grad
#     178         with context_manager():
# --> 179             return loop_run(self, *args, **kwargs)
#     180
#     181     return _decorator
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/evaluation_loop.py in run(self)
#     144                 self.batch_progress.is_last_batch = data_fetcher.done
#     145                 # run step hooks
# --> 146                 self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#     147             except StopIteration:
#     148                 # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/evaluation_loop.py in _evaluation_step(self, batch, batch_idx, dataloader_idx, dataloader_iter)
#     439             else (dataloader_iter,)
#     440         )
# --> 441         output = call._call_strategy_hook(trainer, hook_name, *step_args)
#     442
#     443         self.batch_progress.increment_processed()
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/call.py in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     327
#     328     with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 329         output = fn(*args, **kwargs)
#     330
#     331     # restore current_fx when nested context
#
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/strategies/strategy.py in validation_step(self, *args, **kwargs)
#     410             if self.model != self.lightning_module:
#     411                 return self._forward_redirection(self.model, self.lightning_module, "validation_step", *args, **kwargs)
# --> 412             return self.lightning_module.validation_step(*args, **kwargs)
#     413
#     414     def test_step(self, *args: Any, **kwargs: Any) -> STEP_OUTPUT:
#
# /usr/local/lib/python3.12/dist-packages/anomalib/models/image/patchcore/lightning_model.py in validation_step(***failed resolving arguments***)
#     267
#     268         # Get anomaly maps and predicted scores from the model.
# --> 269         predictions = self.model(batch.image)
#     270
#     271         return batch.update(**predictions._asdict())
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/anomalib/models/image/patchcore/torch_model.py in forward(self, input_tensor)
#     180
#     181         # apply nearest neighbor search
# --> 182         patch_scores, locations = self.nearest_neighbors(embedding=embedding, n_neighbors=1)
#     183         # reshape to batch dimension
#     184         patch_scores = patch_scores.reshape((batch_size, -1))
#
# /usr/local/lib/python3.12/dist-packages/anomalib/models/image/patchcore/torch_model.py in nearest_neighbors(self, embedding, n_neighbors)
#     338             (torch.Size([100, 5]), torch.Size([100, 5]))
#     339         """
# --> 340         distances = self.euclidean_dist(embedding, self.memory_bank)
#     341         if n_neighbors == 1:
#     342             # when n_neighbors is 1, speed up computation by using min instead of topk
#
# /usr/local/lib/python3.12/dist-packages/anomalib/models/image/patchcore/torch_model.py in euclidean_dist(x, y)
#     311         y_norm = y.pow(2).sum(dim=-1, keepdim=True)  # |y|
#     312         # row distance can be rewritten as sqrt(|x| - 2 * x @ y.T + |y|.T)
# --> 313         res = x_norm - 2 * torch.matmul(x, y.transpose(-2, -1)) + y_norm.transpose(-2, -1)
#     314         return res.clamp_min_(0).sqrt_()
#     315
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 12.68 GiB. GPU 0 has a total capacity of 22.16 GiB of which 6.99 GiB is free. Process 20929 has 15.17 GiB memory in use. Of the allocated memory 14.40 GiB is allocated by PyTorch, and 558.24 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ### Predict

# %%
from scripts.train_anomalib import Anomalibs

runner = Anomalibs() # default path: RUNTIME_CONFIG_ROOT
predictions = runner.predict_all()
predictions

# %%
import numpy as np
import torch
import pandas as pd
from sklearn.metrics import (
    roc_auc_score,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    jaccard_score
)

results = []
for category, batches in predictions.items():
    # Image-level
    y_true = np.concatenate([b["gt_label"].cpu().numpy() for b in batches])
    y_score = np.concatenate([b["pred_score"].cpu().numpy() for b in batches])
    y_pred = (y_score >= 0.5).astype(int)

    metrics = {
        "Category": category,
        "AUROC": round(roc_auc_score(y_true, y_score), 4),
        "Accuracy": round(accuracy_score(y_true, y_pred), 4),
        "Precision": round(precision_score(y_true, y_pred, zero_division=0), 4),
        "Recall": round(recall_score(y_true, y_pred, zero_division=0), 4),
        "F1": round(f1_score(y_true, y_pred, zero_division=0), 4),
        "N_samples": len(y_true)
    }

    # Pixel-level (mask가 있는 경우만)
    if "gt_mask" in batches[0] and batches[0]["gt_mask"] is not None:
        gt_masks = torch.cat([b["gt_mask"] for b in batches]).int()
        pred_masks = torch.cat([(b["anomaly_map"] > 0.5).int() for b in batches])

        metrics["Dice"] = round(
            f1_score(
                gt_masks.flatten().cpu().numpy(),
                pred_masks.flatten().cpu().numpy(),
                zero_division=0
            ), 4
        )
        metrics["IoU"] = round(
            jaccard_score(
                gt_masks.flatten().cpu().numpy(),
                pred_masks.flatten().cpu().numpy(),
                average="binary",
                zero_division=0
            ), 4
        )

    results.append(metrics)

metrics_df = pd.DataFrame(results).set_index("Category")
avg_row = metrics_df.drop(columns=["N_samples"]).mean().round(4)
avg_row["N_samples"] = metrics_df["N_samples"].sum()
metrics_df.loc["Average"] = avg_row

metrics_df

# %%
from src.visual.plot import heatmap_plot

metrics_trans = metrics_df.drop('Average').drop(columns='N_samples')
heatmap_plot(
    metrics_trans,
    figsize=(10, 10),
    cmap='RdYlGn',
    annot=True,
    fmt='.4f',
    linewidths=0.5,
    title='EfficientAd Performance by Category',
    rotation_x=45,
    rotation_y=0
)

# %%
from src.visual.plot import visualize_prediction

for category, batches in predictions.items():
    if not batches:
        continue

    batch = batches[0]  # 첫 batch
    visualize_prediction(
        batch=batch,
        idx=0,           # batch 내 첫 이미지
        title=category
    )

# %% [markdown]
# ### Resume training

# %%
config

# %%
from scripts.train_anomalib import Anomalibs

runner = Anomalibs() # default path: RUNTIME_CONFIG_ROOT
runner.fit_all()
